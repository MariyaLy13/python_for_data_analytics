# %% [markdown]
# ![image.png](attachment:8579c524-1cde-4e77-80af-1cae7d5a2ac0.png)

# %% [markdown]
# 1. echo "# My_Data_Project" >> README.md
#
# 3.
# git ini
#    t5.
# git add README.
#    m7. d
# git commit -m "first comm
#    i9. t"
# git branch -M
#     m11. ain
# git remote add origin https://github.com/MariyaLy13/My_Data_Projec
#     t13. .git
# git push -u origi
#
# 15. git remote add origin https://github.com/MariyaLy13/My_Data_Project.git
#
# 17.
# git branch -M mai
#     n19.
# git push -u origin ma
#     inn main

# %% [markdown]
# ![image.png](attachment:0ca5344d-34c4-4194-9524-5b6feb4f4b30.png)

# %% [markdown]
# ![image.png](attachment:c89d5089-4390-40d8-b6ff-db0f05127130.png)

# %% [markdown]
# ![image.png](attachment:782cf2ce-71f1-453e-9f7d-8afecb6448bf.png)

# %% [markdown]
# ![image.png](attachment:5073e14f-b252-4ea3-8b12-49f0cf8ee799.png)

# %% [markdown]
# ![image.png](attachment:e7778117-edc4-4fb7-bd71-9ff99c6da402.png)

# %% [markdown]
# ![image.png](attachment:23bb8a5f-bb11-488b-a880-599c9c81db00.png)

# %% [markdown]
# ![image.png](attachment:81eef2c2-e4ce-4e8b-a527-ed687d31837c.png)

# %% [markdown]
# ![image.png](attachment:2ffb1b00-60e4-472a-bd89-2253b90f037a.png)

# %% [markdown]
# ![image.png](attachment:ba26c398-4ff9-48af-b740-b2baa6185d15.png)

# %% [markdown]
# ![image.png](attachment:f9f52ff6-6f6c-467a-923e-2dfe72c3e754.png)

# %% [markdown]
# ![image.png](attachment:963c5cac-c3f8-4844-8eb7-cb4650b727b1.png)

# %% [markdown]
# ![image.png](attachment:eb66ced8-3c0c-456c-b5b0-6456fdd04278.png)

# %% [markdown]
# ![image.png](attachment:b29bea15-b25c-45df-86d5-87c48ab9518a.png)

# %% [markdown]
# ![image.png](attachment:bbdd6586-a9cb-440f-8d90-8f9bf34826ab.png)

# %% [markdown]
# ![image.png](attachment:1d58bd0e-dd0f-416e-8160-54da1f0a87a2.png)

# %% [markdown]
# ![image.png](attachment:3b68b540-c53b-4d22-ab8a-c9d33b93b7cf.png)

# %% [markdown]
# ![image.png](attachment:52f3de78-f6ef-426e-a663-b58d65264ff4.png)

# %% [markdown]
# ![image.png](attachment:90b39ade-357b-4d0c-bff3-fb133bb9d974.png)

# %% [markdown]
# ![image.png](attachment:6e0b681d-7524-4df7-98c0-599e72ce2b69.png)

# %% [markdown]
# ![image.png](attachment:77a3ba31-6360-49b5-ba44-63980b8638f7.png)

# %% [markdown]
# ![image.png](attachment:4eda5400-8bd0-4808-a50b-2446b50a0f11.png)

# %% [markdown]
# ![image.png](attachment:70fb33f0-4dbd-47ba-b30a-07a9211626ec.png)

# %% [markdown]
# ![image.png](attachment:fb729614-faa7-4200-affc-b7c94b0497eb.png)

# %% [markdown]
# ![image.png](attachment:9e9216d9-14ef-4929-9406-218e71ad0466.png)

# %% [markdown]
# ![image.png](attachment:9b454e77-26e6-4b23-942b-a2bfe74dd945.png)

# %% [markdown]
# ![image.png](attachment:ad61d84b-0114-471a-ada9-64a3ac319f5a.png)

# %% [markdown]
# ![image.png](attachment:4550be3b-c0f0-4e2e-a1d8-c43efb028a2c.png)

# %% [markdown]
# ![image.png](attachment:1dcc19a9-1a96-4c9f-b8e7-0378cb283283.png)

# %% [markdown]
# ![image.png](attachment:406e4261-5bf4-4992-a4c7-d2dd82721a32.png)

# %% [markdown]
# ![image.png](attachment:961a4932-e730-4518-8ce4-ca7d216d5834.png)

# %% [markdown]
# ![image.png](attachment:e3cbe2de-94a4-43c7-b146-a26e941529a8.png)

# %% [markdown]
# ![image.png](attachment:9b52f41b-4b30-4c50-b821-be31b96bb7c1.png)

# %% [markdown]
# ![image.png](attachment:751a4dff-cb60-49b1-adfd-85eda63c8905.png)

# %% [markdown]
# ![image.png](attachment:97282f84-ba74-42b7-9dcc-e43d8fee5c27.png)

# %% [markdown]
# ![image.png](attachment:3b5a8346-01c1-4703-b052-c101a331ba5e.png)

# %% [markdown]
# ![image.png](attachment:667e0214-bb15-4242-bcc4-b4321bd86161.png)

# %% [markdown]
# ![image.png](attachment:a67f8f52-02e1-4811-b49d-9e6666d0c3e0.png)

# %% [markdown]
# ![image.png](attachment:5cca511d-38b7-4359-a3fd-3b77ae122206.png)
